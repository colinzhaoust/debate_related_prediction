# %%
# -*- coding: utf-8 -*-
import json
import os
import random
import numpy as np
import math
import torch
from torch import nn
from torch.nn import init
from torch import optim
import time
from tqdm import tqdm_notebook as tqdm
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import random

import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
import gzip
import gensim
import logging
import os
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import itertools

with open("users.json", "r") as f:
    users = json.load(f)

number_of_users = len(users)
print("Finish User loading, with number of users:", number_of_users)
# print(users.keys())
# print(users["ahuggies30"])
get_big_issues = users["ahuggies30"]["big_issues_dict"].keys()

big_issues_list = []

for item in get_big_issues:
    big_issues_list.append(item)
# Out:
# Finish User loading, with number of users: 45348

# %%
# ############################################
# # Load Word Embedding
# ############################################


# def sent_shuffle(sent):
#     all_sents = []
#     total_length = len(sent)

#     for i in range(10):
#         random.shuffle(sent)
#         all_sents.append(sent[:])

#     return all_sents


# # sent = ["I", "am", "what", "you", "don't", "expect"]
# # all_sents = sent_shuffle(sent)
# # print()
# # print(all_sents)
# # breakpoint()

# with open("users.json", "r") as f:
#     users = json.load(f)

# sentences = []
# # useful_aspects = [ 'education', 'ethnicity', 'income', 'interested', 'looking', 'number_of_friends',  'party', 'political_ideology', 'president', 'relationship', 'religious_ideology', 'win_ratio', 'gender']
# # useful_aspects = ['political_ideology', 'education', 'ethnicity', 'interested', 'gender',"religious_ideology"]
# useful_aspects = ['political_ideology','education', 'gender', "religious_ideology", "party", "ethnicity"]

# for user in users.values():
#     user_sent = []

#     for aspect in useful_aspects:

#         if user[aspect] == "Not Saying":
#             continue
#         else:
#             # user_sent.append(aspect + ":" + user[aspect])
#             user_sent.append(user[aspect])

#     for key in user["big_issues_dict"].keys():

#         for choice in ["Pro", "Con"]: # , "Und", "N/O"]:
#             this_sent = user_sent
#             if user["big_issues_dict"][key] == choice:
#                 this_sent.append(key + "-" + choice)
#                 if len(this_sent) > 0:
#                     sent_list = this_sent
#                     if len(sent_list) > 0:
#                         sentences.extend(sent_list)


# print("Total number of sentences generated", len(sentences))

# language_model = Word2Vec(sentences, size=8, window=20, sg=0)
# # language_model = Word2Vec.load("user_aspect_embedding.bin")
# print("Finish loading the word vector")

# %%
# language_model.wv.save("user_ascpect_embedding.bin")

language_model = Word2Vec.load("user_aspect_embedding.bin")

# %%
# Helper Function

def target_counter(target_list, users):
    target_counters = dict()
    for target in target_list:
        target_counters[target] = dict()

    for user in users.values():
        for target in target_list:
            if not target_counters[target].get(user[target]):
                if "Christian" in  user[target]:
                    user[target] = "Christian"
                target_counters[target][user[target]] = 1
            else:
                if "Christian" in  user[target]:
                    user[target] = "Christian"
                target_counters[target][user[target]] += 1

    return target_counters


def criterion_generator(target_list, target_counters, bar):
    criterion = dict()

    for target in target_list:
        criterion[target] = []
        for item in target_counters[target].keys():
            if item == "Not Saying":
                continue
            if target_counters[target][item] > bar:
                criterion[target].append(item)
        if len(criterion[target]) == 0:
            del criterion[target]

    return criterion

religious_ideology = "religious_ideology"  # Christian or Atheist
political_ideology = "political_ideology"  # Liberal or Conservative


def user_filter(users, target_list, bar):
    target_counters = target_counter(target_list, users)
    criterion = criterion_generator(target_list, target_counters, bar)

    valid_users = []
    for user in users.values():
        indicator = 1

        for key in criterion.keys():
            if not user.get(key):
                indicator = 0
                break
            elif user.get(key) not in criterion[key]:
                indicator = 0
                break

        if indicator:
            valid_users.append(user)

    # print("Number of valid users:", len(valid_users))
    return valid_users, criterion

number = 0


def get_user_aspect_vec(user, criterion, model, target_big_issues):
    user_aspect_vec = []
    for key in criterion.keys():
        init = [0.0 for i in range(len(criterion[key]))]

        if user[key] in criterion[key]:
            index = criterion[key].index(user[key])
            init[index] = 1.0
        
        # one-hot
        user_aspect_vec.extend(init)

        # Embedding
        w2v_vec = model.wv[user[key]]
        user_aspect_vec.extend(w2v_vec)

        # Similarity
        sim_pro_sum = 0
        sim_con_sum = 0
        sim_pro_mul = 0
        sim_con_mul = 0

        for target_big_issue in target_big_issues:
            # choice = user["big_issues_dict"][target_big_issue]
            try:
                # w2v_vec_issue = model.wv[target_big_issue + "-" + choice]
                choice1 = "Pro"
                choice2 = "Con"
                sim_pro = model.wv.similarity(user[key], target_big_issue + "-" + choice1)
                sim_con = model.wv.similarity(user[key], target_big_issue + "-" + choice2)
                # user_aspect_vec.append(sim_pro)
                # user_aspect_vec.append(sim_con)
                # user_aspect_vec.append(sim_pro/sim_con)
                # user_aspect_vec.append(sim_pro - sim_con)
                sim_pro_sum += sim_pro
                sim_con_sum += sim_con
                if sim_pro == 0:
                    sim_pro = 0.0001
                if sim_con == 0:
                    sim_con = 0.0001
                sim_pro_mul *= sim_pro
                sim_con_mul *= sim_con
            except:
                global number
                number += 1
                print("Number of missing in similarity part", number)
                user_aspect_vec.extend(np.array(w2v_vec) - np.array(w2v_vec_issue))

    user_aspect_vec.append(sim_pro_sum)
    user_aspect_vec.append(sim_con_sum)
    user_aspect_vec.append(sim_pro_sum/sim_con_sum)
    user_aspect_vec.append(sim_pro_sum - sim_con_sum)

    return user_aspect_vec


def language_feature_generator(text):

    zero = [0.0, 0.0, 0.0, 0.0]

    if len(text) == 0:
        return zero

    sent_tokenize_list = sent_tokenize(text)

    average_sent_length = 0.0
    average_sent_subjectivity = 0.0
    average_sent_polarity = 0.0

    count = 0
    for sentence in sent_tokenize_list:
        count += 1
        sent_blob = TextBlob(sentence)
        average_sent_subjectivity += sent_blob.sentiment.subjectivity
        average_sent_polarity += sent_blob.sentiment.polarity
        average_sent_length += len(word_tokenize(sentence))

    if count == 0:
        return zero

    average_sent_length = float(average_sent_length / count)
    average_sent_subjectivity = float(average_sent_subjectivity / count)
    average_sent_polarity = float(average_sent_polarity / count)

    return len(sent_tokenize(text)), average_sent_length, average_sent_subjectivity, average_sent_polarity


def get_user_language_vec(user):
    language_vec = []

    if not user.get("opinion_arguments"):
        return [0.0 for i in range(4)]

    arguments = user["opinion_arguments"]
    # number of opinions
    # language_vec.append(float(len(arguments)))

    average_sentence_number = 0.0
    average_sentence_length = 0.0
    average_sentence_sub = 0.0
    average_sentence_polar = 0.0

    opinion_count = 0
    for opinion in arguments:
        opinion_count += 1
        sent_number, sent_length, sent_sub, sent_polar = language_feature_generator(opinion["opinion text"])
        average_sentence_number += sent_number
        average_sentence_length += sent_length
        average_sentence_sub += sent_sub
        average_sentence_polar += sent_polar

    average_sentence_number/opinion_count
    average_sentence_length/opinion_count
    average_sentence_sub = average_sentence_sub / opinion_count
    average_sentence_polar = average_sentence_polar / opinion_count

    language_vec.append(average_sentence_number)
    language_vec.append(average_sentence_length)
    language_vec.append(average_sentence_sub)
    language_vec.append(average_sentence_polar)

    return language_vec

# %%
target_big_issue = ["Drug Legalization", "Medical Marijuana"]#,"Gay Marriage"]

# my_user = users["ahuggies30"]
# my_user = users["yomama12"]
# print("Example of user aspect vector: ", get_user_aspect_vec(my_user, criterion, language_model, target_big_issue))
# print("Example of user language vector", get_user_language_vec(my_user))

# %%
def get_training_set(users, target_big_issue, big_issue_list, criterion, w2v_model):
    xTr = []
    yTr = []
    # possible = ["Pro", "Con", "N/O", "N/S", "Und"]
    possible = ["Pro", "Con", "N/O", "Und"]
    see = dict()
    for i in possible:
        see[i] = 0

    for user in users:
        vec = get_user_aspect_vec(user, criterion, w2v_model, target_big_issue)
        label = []
        for target in target_big_issue:
            if user["big_issues_dict"][target] == "N/S":
                continue
            elif user["big_issues_dict"][target] == "N/O" or user["big_issues_dict"][target] == "Und":
                continue
                label.extend([0.0, 1.0])
            else:
                # mask = [0.0, 0.0, 0.0, 0.0]
                mask = [0.0, 0.0]
                mask[possible.index(user["big_issues_dict"][target])] = 1.0
                label.extend(mask)

        # see[possible[label]] += 1

        # vec.extend(get_user_language_vec(user))

        if vec and len(label) == 2 * len(target_big_issue):
            # no N/S
            xTr.append(vec)
            yTr.append(label)

    return xTr, yTr


class model(nn.Module):

    def __init__(self, vocab_size, hidden_dim=64, out_dim=2, output_size=3):
        super(model, self).__init__()
        self.hidden_dim = hidden_dim
        self.out_dim = out_dim
        self.embeds = nn.Linear(vocab_size, hidden_dim)
        self.encoder = nn.Linear(hidden_dim, hidden_dim)

        self.out = nn.Linear(hidden_dim, out_dim * output_size)

        self.loss = nn.BCELoss(reduction='mean')
        # self.loss = nn.MultiLabelMarginLoss()
        

        self.output_size = output_size
        self.indicator = 1

    def compute_loss(self, pred_vec, gold_seq):
        
#         criterion = nn.CrossEntropyLoss()
#         loss = 0
#         for lx in range(len(pred_vec))
        
        return self.loss(pred_vec, gold_seq)

    def forward(self, input_vectors):
        #         input_vectors = self.embeds(torch.tensor(input_seq))

        input_vectors = self.embeds(input_vectors)
        # hidden = input_vectors
        # input_vectors = input_vectors.unsqueeze(1)
        # _, hidden = self.encoder(input_vectors)
        # print(output.size())
        input_vectors = torch.nn.functional.leaky_relu(input_vectors, negative_slope=0.01, inplace=False)
        hidden = self.encoder(input_vectors)
        hidden = torch.nn.functional.leaky_relu(hidden, negative_slope=0.01, inplace=False)
        hidden = self.encoder(hidden)
        output = torch.nn.functional.leaky_relu(hidden, negative_slope=0.01, inplace=False)
        output = self.out(output)
        predictions = torch.sigmoid(output)
        predictions = predictions.squeeze()

        # print("predictions:", predictions)
        idxs = []
        for i in range(self.output_size):
            prediction = predictions[(i * self.out_dim):((i + 1)) * self.out_dim]
            prediction = prediction.squeeze()
            val, idx = torch.max(prediction, 0)
            # idx = idx.item
            if idx == 0:
                # idxs.extend([1.0, 0.0, 0.0, 0.0])
                idxs.extend([1.0, 0.0])
            elif idx == 1:
                idxs.extend([0.0, 1.0])
                # idxs.extend([0.0, 1.0, 0.0, 0.0])
            elif idx == 2:
                idxs.extend([0.0, 0.0, 1.0])
            elif idx == 3:
                idxs.extend([0.0, 0.0, 0.0, 1.0])

        return predictions, idxs

# %%
################### Find the nearest via Embedding ##########################
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

sentences = []

for user in users.values():
    user_pro = []
    user_con = []
    user_und = []
    user_no = []
    # print(user["big_issues_dict"])
    for key in user["big_issues_dict"].keys():
        if user["big_issues_dict"][key] == "Pro":
            user_pro.append(key)
        if user["big_issues_dict"][key] == "Con":
            user_con.append(key)
        if user["big_issues_dict"][key] == "Und":
            user_und.append(key)
        if user["big_issues_dict"][key] == "N/O":
            user_no.append(key)

    if len(user_pro) > 0:
        sentences.append(user_pro)
    if len(user_con) > 0:
        sentences.append(user_con)
    if len(user_und) > 0:
        sentences.append(user_und)
    if len(user_no) > 0:
        sentences.append(user_no)

print(len(sentences))

bi_model = Word2Vec(sentences, size=5, window=50)
print(bi_model)
# Out:
# 53905
# Word2Vec(vocab=48, size=5, alpha=0.025)

# %%
words = list(bi_model.wv.vocab)
embedding_results = dict()

for word in words:
    # print(word)
    po_list = bi_model.most_similar(positive=[word])
    # print(type(list))
    # print(model.most_similar(positive=[word]))
    
    prior_list = []
    for item in po_list:
        prior_list.append(item[0])
        
    embedding_results[word] = prior_list
    
print(embedding_results)
# Out:
# C:\Users\xzhao\Anaconda3\envs\4901\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# {'Abortion': ['Global Warming Exists', 'Drug Legalization', 'Environmental Protection', 'Medical Marijuana', 'Euthanasia', 'Medicaid & Medicare', 'Minimum Wage', 'Civil Unions', 'Animal Rights', 'United Nations'], 'Animal Rights': ['Civil Unions', 'Environmental Protection', 'Medical Marijuana', 'Drug Legalization', 'Gay Marriage', 'Legalized Prostitution', 'Minimum Wage', 'Euthanasia', 'Welfare', 'United Nations'], 'Barack Obama': ['European Union', 'Socialism', 'Occupy Movement', 'Affirmative Action', 'Estate Tax', 'Progressive Tax', 'Stimulus Spending', 'Term Limits', 'Labor Union', 'Redistribution'], 'Capitalism': ['Homeschooling', 'Free Trade', 'Electoral College', 'Gold Standard', 'European Union', 'Barack Obama', 'Occupy Movement', 'Socialism', 'Redistribution', 'Stimulus Spending'], 'Environmental Protection': ['Medical Marijuana', 'Global Warming Exists', 'Abortion', 'Drug Legalization', 'Animal Rights', 'Minimum Wage', 'Civil Unions', 'Gay Marriage', 'Euthanasia', 'United Nations'], 'European Union': ['Socialism', 'Occupy Movement', 'Stimulus Spending', 'Barack Obama', 'Redistribution', 'Free Trade', 'National Retail Sales Tax', 'Estate Tax', 'Affirmative Action', 'Progressive Tax'], 'Euthanasia': ['Medicaid & Medicare', 'Civil Unions', 'Minimum Wage', 'Social Programs', 'Abortion', 'United Nations', 'Drug Legalization', 'Global Warming Exists', 'Welfare', 'Animal Rights'], 'Federal Reserve': ['Flat Tax', 'Occupy Movement', 'Estate Tax', 'Affirmative Action', 'Socialism', 'Globalization', 'Gold Standard', 'Redistribution', 'Military Intervention', 'Stimulus Spending'], 'Free Trade': ['European Union', 'Stimulus Spending', 'Barack Obama', 'Redistribution', 'Capitalism', 'National Retail Sales Tax', 'Socialism', 'Occupy Movement', 'Euthanasia', 'Gold Standard'], 'Gay Marriage': ['Medical Marijuana', 'Animal Rights', 'Environmental Protection', 'National Health Care', 'Drug Legalization', 'Legalized Prostitution', 'Civil Unions', 'Welfare', 'United Nations', 'Minimum Wage'], 'Global Warming Exists': ['Abortion', 'Environmental Protection', 'Drug Legalization', 'Medical Marijuana', 'Medicaid & Medicare', 'Euthanasia', 'Minimum Wage', 'Civil Unions', 'Animal Rights', 'United Nations'], 'Globalization': ['Legalized Prostitution', 'Federal Reserve', 'Labor Union', 'Affirmative Action', 'Barack Obama', 'Progressive Tax', 'Homeschooling', 'Estate Tax', 'Socialism', 'National Health Care'], 'Labor Union': ['National Health Care', 'Social Security', 'Welfare', 'Term Limits', 'Progressive Tax', 'United Nations', 'Social Programs', 'Affirmative Action', 'Civil Unions', 'Barack Obama'], 'Legalized Prostitution': ['Globalization', 'Labor Union', 'National Health Care', 'Animal Rights', 'Barack Obama', 'Homeschooling', 'Civil Unions', 'Welfare', 'Social Security', 'Term Limits'], 'Medical Marijuana': ['Environmental Protection', 'Gay Marriage', 'Drug Legalization', 'Animal Rights', 'Abortion', 'Global Warming Exists', 'Minimum Wage', 'Civil Unions', 'United Nations', 'Welfare'], 'Military Intervention': ['Electoral College', 'Flat Tax', 'Internet Censorship', 'Gold Standard', 'Border Fence', 'Federal Reserve', 'Racial Profiling', 'Redistribution', 'Torture', 'War on Terror'], 'Minimum Wage': ['United Nations', 'Civil Unions', 'Welfare', 'Social Programs', 'Social Security', 'Medicaid & Medicare', 'Euthanasia', 'Term Limits', 'Environmental Protection', 'Labor Union'], 'National Health Care': ['Labor Union', 'Social Security', 'Welfare', 'Legalized Prostitution', 'United Nations', 'Term Limits', 'Civil Unions', 'Social Programs', 'Minimum Wage', 'Progressive Tax'], 'Progressive Tax': ['Affirmative Action', 'Estate Tax', 'Term Limits', 'Socialism', 'Labor Union', 'Occupy Movement', 'Barack Obama', 'Smoking Ban', 'Social Security', 'Social Programs'], 'Redistribution': ['Stimulus Spending', 'Occupy Movement', 'Socialism', 'European Union', 'National Retail Sales Tax', 'Estate Tax', 'Gold Standard', 'Affirmative Action', 'Barack Obama', ...

# %%
print(embedding_results["Abortion"])

this = np.copy(embedding_results["Abortion"])
np.random.shuffle(this)
# print(this)

# print(embedding_results["Abortion"])
# Out:
# ['Global Warming Exists', 'Drug Legalization', 'Environmental Protection', 'Medical Marijuana', 'Euthanasia', 'Medicaid & Medicare', 'Minimum Wage', 'Civil Unions', 'Animal Rights', 'United Nations']

# %%
###### coll = []
acc_collection = dict()
list_len = len(big_issues_list)

from random import randint

target_list = ['political_ideology', 'education', 'gender', "religious_ideology"]

# target_list = ['political_ideology','education', 'gender', "religious_ideology", "party", "ethnicity"]
valid_users, criterion = user_filter(users, target_list, 5)


for k in [5, 6, 7, 8]:
    
    acc_collection[k] = dict()
    
    for i in range(list_len):
    
#         target = big_issues_list[i]
#         print(str(i+1) + "/"+ str(list_len))
#         print(target)
#         target_big_issue = [target]

#         # Use all together
#         temp = big_issues_list
#         temp[0], temp[i] = temp[i], temp[0]
#         target_big_issue = temp
#         print(str(i) + "/"+ str(list_len))
#         print(temp[0])

        # K

        target = big_issues_list[i]
        print(str(i+1) + "/"+ str(list_len))
        print(target)
        target_big_issue = [target]
        
        if k == 1:
            print("single task")
        else:
            aux = embedding_results[target][0:k-1]
            target_big_issue.extend(aux)
            print(aux)
        
        
        # Rand
#         target = big_issues_list[i]
#         print(str(i+1) + "/"+ str(list_len))
#         print(target)
#         target_big_issue = [target]
    
        
#         rand_n = 1
#         temp = np.copy(embedding_results[target])
#         np.random.shuffle(temp)
        
#         aux = temp[0:rand_n]

        
#         target_big_issue.extend(aux)
#         print(aux)   
        
        

        # valid_users, criterion = user_filter(users, target_list, 200)
        unbalanced_xTr, unbalanced_yTr = get_training_set(valid_users, target_big_issue, big_issues_list, criterion, language_model)

        xTr = []
        yTr = []

        number_of_0 = 0
        number_of_1 = 0

        # Find the smaller set
        for i in range(len(unbalanced_xTr)):
            if unbalanced_yTr[i][0] == 0:
                    number_of_0 += 1
            if unbalanced_yTr[i][0] == 1:
                    number_of_1 += 1

        if number_of_0 > number_of_1:
            number_each = number_of_1
        else:
            number_each = number_of_0

        number_of_0 = 0
        number_of_1 = 0

        for i in range(len(unbalanced_xTr)):
            if unbalanced_yTr[i][0] == 0:
                if number_of_0 < number_each:
                    xTr.append(unbalanced_xTr[i])
                    yTr.append(unbalanced_yTr[i])
                    number_of_0 += 1
            if unbalanced_yTr[i][0] == 1:
                if number_of_1 < number_each:
                    xTr.append(unbalanced_xTr[i])
                    yTr.append(unbalanced_yTr[i])
                    number_of_1 += 1

    #     print(len(xTr), len(yTr))
    #     print(number_of_0, number_of_1)


        mask = np.arange(2 * number_each)
        np.random.shuffle(mask)

        temp_xTr = []
        temp_yTr = []

        for pick in mask:
            temp_xTr.append(xTr[pick])
            temp_yTr.append(yTr[pick])

        xTr = temp_xTr
        yTr = temp_yTr

    #     print(len(xTr), len(yTr))
    #     print(len(xTr[0]), len(yTr[0]))


        # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        device = torch.device("cpu")

        m = model(len(xTr[0]), 64, 2, len(target_big_issue)).to(device)
        optimizer = optim.SGD(m.parameters(), lr=0.1)

        training_x = xTr[0:int(0.8 * len(xTr))]
        training_y = yTr[0:int(0.8 * len(yTr))]
        test_x = xTr[int(0.8 * len(xTr)):]
        test_y = yTr[int(0.8 * len(yTr)):]
        
        print(len(yTr))

        for epoch in (range(15)):
            m.train()
#             print('training')
            start_train = time.time()
            total_loss = 0

            total_predictions = 0
            correct = 0

            for i in range(int(len(training_x)/10)):
                # print(torch.cuda.current_device())
                predictions = None
                gold_outputs = None
                loss = 0
                optimizer.zero_grad()

                for j in range(10):
                    loss = 0

#                     if torch.cuda.is_available():
#                         gold_output = torch.cuda.FloatTensor(training_y[i + j], device=device)
#                         input_seq = torch.cuda.FloatTensor(training_x[i + j], device=device)
#                     else:
                    gold_output = torch.FloatTensor(training_y[i + j], device=device)
                    input_seq = torch.FloatTensor(training_x[i + j], device=device)

                    prediction_vec, prediction = m(input_seq)

                    total_predictions += 1
                    # gold_outputs = []
                    if prediction[0:2] == training_y[i + j][0:2]:
                        correct += 1
                    if predictions is None:
                        predictions = [prediction_vec]
                        gold_outputs = [gold_output]
                    else:
                        predictions.append(prediction_vec)
                        gold_outputs.append(gold_output)
                    #
                    # for lx in range(len(gold_output)):
                    #     tmp_loss = m.compute_loss(prediction[lx], gold_output[lx])
                    #     loss += tmp_loss

                # print(torch.stack(gold_outputs))
                # print(torch.stack(predictions))
                loss = m.compute_loss(torch.stack(predictions), torch.stack(gold_outputs).squeeze())
                # loss = loss/len(target_big_issue)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
            accuracy = correct / total_predictions
#             print("training time: {} for epoch {}".format(time.time() - start_train, epoch))
#             print('total loss:{}'.format(total_loss))
#             print('training accuracy:{}'.format(accuracy))

        m.eval()
        predictions = 0
        correct = 0
        baseline = 0

        max_score = 0
        for i in range(int(len(test_x))):
#             if torch.cuda.is_available():
#                 gold_output = torch.cuda.FloatTensor(test_y[i], device=device)
#                 input_seq = torch.cuda.FloatTensor(test_x[i], device=device)
#             else:
            gold_output = torch.tensor(test_y[i], device=device)
            input_seq = torch.FloatTensor(test_x[i], device=device)

            _, prediction = m(input_seq)

            # print("prediction", prediction)
            # print("test_y", test_y[i])

            if test_y[i][0:2] == prediction[0:2]:
                correct += 1
            if test_y[i][0:2] == [0.0, 1.0]:
                baseline += 1
            predictions += 1

        accuracy = correct / predictions
        
        acc_collection[k][target] = accuracy
        # baseline = baseline / predictions
        assert 0 <= accuracy <= 1
        print('Accuracy:{}'.format(accuracy))
        # print('Baseline:{}'.format(baseline))

    print(acc_collection[k])
# Out:
# 1/48
# Abortion
# ['Global Warming Exists', 'Drug Legalization', 'Environmental Protection', 'Medical Marijuana']
# 596
# Accuracy:0.5916666666666667
# 2/48
# Affirmative Action
# ['Estate Tax', 'Progressive Tax', 'Socialism', 'Term Limits']
# 300
# Accuracy:0.6333333333333333
# 3/48
# Animal Rights
# ['Civil Unions', 'Environmental Protection', 'Medical Marijuana', 'Drug Legalization']
# 256
# Accuracy:0.6346153846153846
# 4/48
# Barack Obama
# ['European Union', 'Socialism', 'Occupy Movement', 'Affirmative Action']
# 292
# Accuracy:0.6779661016949152
# 5/48
# Border Fence
# ['Racial Profiling', 'Flat Tax', 'Military Intervention', 'War on Terror']
# 436
# Accuracy:0.6022727272727273
# 6/48
# Capitalism
# ['Homeschooling', 'Free Trade', 'Electoral College', 'Gold Standard']
# 218
# Accuracy:0.5227272727272727
# 7/48
# Civil Unions
# ['Minimum Wage', 'United Nations', 'Welfare', 'Social Programs']
# 466
# Accuracy:0.48936170212765956
# 8/48
# Death Penalty
# ['War in Afghanistan', 'Racial Profiling', 'Border Fence', 'Gun Rights']
# 1180
# Accuracy:0.6652542372881356
# 9/48
# Drug Legalization
# ['Abortion', 'Environmental Protection', 'Medical Marijuana', 'Global Warming Exists']
# 772
# Accuracy:0.535483870967742
# 10/48
# Electoral College
# ['Gold Standard', 'Military Intervention', 'Internet Censorship', 'Flat Tax']
# 250
# Accuracy:0.48
# 11/48
# Environmental Protection
# ['Medical Marijuana', 'Global Warming Exists', 'Abortion', 'Drug Legalization']
# 410
# Accuracy:0.6341463414634146
# 12/48
# Estate Tax
# ['Affirmative Action', 'Progressive Tax', 'Socialism', 'Occupy Movement']
# 344
# Accuracy:0.43478260869565216
# 13/48
# European Union
# ['Socialism', 'Occupy Movement', 'Stimulus Spending', 'Barack Obama']
# 320
# Accuracy:0.40625
# 14/48
# Euthanasia
# ['Medicaid & Medicare', 'Civil Unions', 'Minimum Wage', 'Social Programs']
# 280
# Accuracy:0.5
# 15/48
# Federal Reserve
# ['Flat Tax', 'Occupy Movement', 'Estate Tax', 'Affirmative Action']
# 322
# Accuracy:0.5230769230769231
# 16/48
# Flat Tax
# ['Military Intervention', 'Federal Reserve', 'Gold Standard', 'Electoral College']
# 258
# Accuracy:0.5384615384615384
# 17/48
# Free Trade
# ['European Union', 'Stimulus Spending', 'Barack Obama', 'Redistribution']
# 166
# Accuracy:0.5294117647058824
# 18/48
# Gay Marriage
# ['Medical Marijuana', 'Animal Rights', 'Environmental Protection', 'National Health Care']
# 188
# Accuracy:0.6052631578947368
# 19/48
# Global Warming Exists
# ['Abortion', 'Environmental Protection', 'Drug Legalization', 'Medical Marijuana']
# 508
# Accuracy:0.5588235294117647
# 20/48
# Globalization
# ['Legalized Prostitution', 'Federal Reserve', 'Labor Union', 'Affirmative Action']
# 228
# Accuracy:0.4782608695652174
# 21/48
# Gold Standard
# ['Electoral College', 'Military Intervention', 'Internet Censorship', 'Redistribution']
# 348
# Accuracy:0.5857142857142857
# 22/48
# Gun Rights
# ['Death Penalty', 'Smoking Ban', 'Homeschooling', 'Legalized Prostitution']
# 464
# Accuracy:0.6774193548387096
# 23/48
# Homeschooling
# ['Capitalism', 'Barack Obama', 'Legalized Prostitution', 'Globalization']
# 344
# Accuracy:0.5797101449275363
# 24/48
# Internet Censorship
# ['Electoral College', 'Military Intervention', 'Gold Standard', 'Torture']
# 112
# Accuracy:0.5217391304347826
# 25/48
# Iran-Iraq War
# ['Torture', 'War on Terror', 'Internet Censorship', 'Electoral College']
# 158
# Accuracy:0.59375
# 26/48
# Labor Union
# ['National Health Care', 'Social Security', 'Welfare', 'Term Limits']
# 578
# Accuracy:0.6637931034482759
# 27/48
# Legalized Prostitution
# ['Globalization', 'Labor Union', 'National Health Care', 'Animal Rights']
# 232
# Accuracy:0.425531914893617
# 28/48
# Medicaid & Medicare
# ['Minimum Wage', 'Euthanasia', 'Social Programs', 'Civil Unions']
# 422
# Accuracy:0.7294117647058823
# 29/48
# Medical Marijuana
# ['Environmental Protection', 'Gay Marriage', 'Drug Legalization', 'Animal Rights']
# 166
# Accuracy:0.5
# 30/48
# Military Intervention
# ['Electoral College', 'Flat Tax', 'Internet Censorship', 'Gold Standard']
# 354
# Accuracy:0.5211267605633803
# 31/48
# Minimum Wage
# ['United Nations', 'Civil Unions', 'Welfare', 'Social Programs']
# 606
# Accuracy:0.7295081967213115
# 32/48
# National Health Care
# ['Labor Union', 'Social Security', 'Welfare', 'Legalized Prostitution']
# 380
# Accuracy:0.4342105263157895
# 33/48
# National Retail Sales Tax
# ['Stimulus Spending', 'Redistribution', 'Socialism', 'Occupy Movement']
# 334
# Accuracy:0.5074626865671642
# 34/48
# Occupy Movement
# ['Socialism', 'Stimulus Spending', 'Redistribution', 'Estate Tax']
# 358
# Accuracy:0.5138888888888888
# 35/48
# Progressive Tax
# ['Affirmative Action', 'Estate Tax', 'Term Limits', 'Socialism']
# 412
# Accuracy:0.7228915662650602
# 36/48
# Racial Profiling
# ['Border Fence', 'War in Afghanistan', 'Flat Tax', 'Military Intervention']
# 222
# Accuracy:0.4666666666666667
# 37/48
# Redistribution
# ['Stimulus Spending', 'Occupy Movement', 'Socialism', 'European Union']
# 326
# Accuracy:0.7272727272727273
# 38/48
# Smoking Ban
# ['Term Limits', 'Affirmative Action', 'Progressive Tax', 'Estate Tax']
# 812
# Accuracy:0.5030674846625767
# 39/48
# Social Programs
# ['United Nations', 'Social Security', 'Welfare', 'Minimum Wage']
# 634
# Accuracy:0.7874015748031497
# 40/48
# Social Security
# ['Welfare', 'United Nations', 'Social Programs', 'Minimum Wage']
# 676
# Accuracy:0.6838235294117647
# 41/48
# Socialism
# ['Occupy Movement', 'Estate Tax', 'Stimulus Spending', 'European Union']
# 326
# Accuracy:0.48484848484848486
# 42/48
# Stimulus Spending
# ['Redistribution', 'Occupy Movement', 'Socialism', 'European Union']
# 326
# Accuracy:0.6515151515151515
# 43/48
# Term Limits
# ['Smoking Ban', 'Social Security', 'Progressive Tax', 'Affirmative Action']
# 472
# Accuracy:0.5263157894736842
# 44/48
# Torture
# ['Internet Censorship', 'Iran-Iraq War', 'War on Terror', 'Electoral College']
# 336
# Accuracy:0.5147058823529411
# 45/48
# United Nations
# ['Welfare', 'Social Security', 'Minimum Wage', 'Social Programs']
# 706
# Accuracy:0.5845070422535211
# 46/48
# War in Afghanistan
# ['Racial Profiling', 'Death Penalty', 'Border Fence', 'Flat Tax']
# 624
# Accuracy:0.568
# 47/48
# War on Terror
# ['Iran-Iraq War', 'Border Fence', 'Internet Censorship', 'Torture']
# 424
# Accuracy:0.4823529411764706
# 48/48
# Welfare
# ['Social Security', 'United Nations', 'Social Programs', 'Minimum Wage']
# 810
# Accuracy:0.6172839506172839
# {'Abortion': 0.5916666666666667, 'Affirmative Action': 0.6333333333333333, 'Animal Rights': 0.6346153846153846, 'Barack Obama': 0.6779661016949152, 'Border Fence': 0.6022727272727273, 'Capitalism': 0.5227272727272727, 'Civil Unions': 0.48936170212765956, 'Death Penalty': 0.6652542372881356, 'Drug Legalization': 0.535483870967742, 'Electoral College': 0.48, 'Environmental Protection': 0.6341463414634146, 'Estate Tax': 0.43478260869565216, 'European Union': 0.40625, 'Euthanasia': 0.5, 'Federal Reserve': 0.5230769230769231, 'Flat Tax': 0.5384615384615384, 'Free Trade': 0.5294117647058824, 'Gay Marriage': 0.6052631578947368, 'Global Warming Exists': 0.5588235294117647, 'Globalization': 0.4782608695652174, 'Gold Standard': 0.5857142857142857, 'Gun Rights': 0.6774193548387096, 'Homeschooling': 0.5797101449275363, 'Internet Censorship': 0.5217391304347826, 'Iran-Iraq War': 0.59375, 'Labor Union': 0.6637931034482759, 'Legalized Prostitution': 0.425531914893617, 'Medicaid & Medicare': 0.7294117647058823, 'Medical Marijuana': 0.5, 'Military Intervention': 0.5211267605633803, 'Minimum Wage': 0.7295081967213115, 'National Health Care': 0.4342105263157895, 'National Retail Sales Tax': 0.5074626865671642, 'Occupy Movement': 0.5138888888888888, 'Progressive Tax': 0.7228915662650602, 'Racial Profiling': 0.4666666666666667, 'Redistribution': 0.7272727272727273, 'Smoking Ban': 0.5030674846625767, 'Social Programs': 0.7874015748031497, 'Social Security': 0.6838235294117647, 'Socialism': 0.48484848484848486, 'Stimulus Spending': 0.6515151515151515, 'Term Limits': 0.5263157894736842, 'Torture': 0.5147058823529411, 'United Nations': 0.5845070422535211, 'War in Afghanistan': 0.568, 'War on Terror': 0.4823529411764706, 'Welfare': 0.6172839506172839}
# 1/48
# Abortion
# ['Global Warming Exists', 'Drug Legalization', 'Environmental Protection', 'Medical Marijuana', 'Euthanasia']
# 386
# Accuracy:0.717948717948718
# 2/48
# Affirmative Action
# ['Estate Tax', 'Progressive Tax', 'Socialism', 'Term Limits', 'Occupy Movement']
# 256
# Accuracy:0.5192307692307693
# 3/48
# Animal Rights
# ['Civil Unions', 'Environmental Protection', 'Medical Marijuana', 'Drug Legalization', 'Gay Marriage']
# 238
# Accuracy:0.5
# 4/48
# Barack Obama
# ['European Union', 'Socialism', 'Occupy Movement', 'Affirmative Action', 'Estate Tax']
# 252
# Accuracy:0.45098039215686275
# 5/48
# Border Fence
# ['Racial Profiling', 'Flat Tax', 'Military Intervention', 'War on Terror', 'Internet Censorship']
# 426
# Accuracy:0.5232558139534884
# 6/48
# Capitalism
# ['Homeschooling', 'Free Trade', 'Electoral College', 'Gold Standard', 'European Union']
# 190
# Accuracy:0.5526315789473685
# 7/48
# Civil Unions
# ['Minimum Wage', 'United Nations', 'Welfare', 'Social Programs', 'Social Security']
# 452
# Accuracy:0.5714285714285714
# 8/48
# Death Penalty
# ['War in Afghanistan', 'Racial Profiling', 'Border Fence', 'Gun Rights', 'Flat Tax']
# 900
# Accuracy:0.6
# 9/48
# Drug Legalization
# ['Abortion', 'Environmental Protection', 'Medical Marijuana', 'Global Warming Exists', 'Civil Unions']
# 610
# Accuracy:0.5409836065573771
# 10/48
# Electoral College
# ['Gold Standard', 'Military Intervention', 'Internet Censorship', 'Flat Tax', 'Federal Reserve']
# 222
# Accuracy:0.5333333333333333
# 11/48
# Environmental Protection
# ['Medical Marijuana', 'Global Warming Exists', 'Abortion', 'Drug Legalization', 'Animal Rights']
# 202
# Accuracy:0.5121951219512195
# 12/48
# Estate Tax
# ['Affirmative Action', 'Progressive Tax', 'Socialism', 'Occupy Movement', 'Stimulus Spending']
# 290
# Accuracy:0.5862068965517241
# 13/48
# European Union
# ['Socialism', 'Occupy Movement', 'Stimulus Spending', 'Barack Obama', 'Redistribution']
# 300
# Accuracy:0.5
# 14/48
# Euthanasia
# ['Medicaid & Medicare', 'Civil Unions', 'Minimum Wage', 'Social Programs', 'Abortion']
# 260
# Accuracy:0.40384615384615385
# 15/48
# Federal Reserve
# ['Flat Tax', 'Occupy Movement', 'Estate Tax', 'Affirmative Action', 'Socialism']
# 308
# Accuracy:0.532258064516129
# 16/48
# Flat Tax
# ['Military Intervention', 'Federal Reserve', 'Gold Standard', 'Electoral College', 'Border Fence']
# 242
# Accuracy:0.40816326530612246
# 17/48
# Free Trade
# ['European Union', 'Stimulus Spending', 'Barack Obama', 'Redistribution', 'Capitalism']
# 158
# Accuracy:0.53125
# 18/48
# Gay Marriage
# ['Medical Marijuana', 'Animal Rights', 'Environmental Protection', 'National Health Care', 'Drug Legalization']
# 180
# Accuracy:0.4166666666666667
# 19/48
# Global Warming Exists
# ['Abortion', 'Environmental Protection', 'Drug Legalization', 'Medical Marijuana', 'Medicaid & Medicare']
# 448
# Accuracy:0.6
# 20/48
# Globalization
# ['Legalized Prostitution', 'Federal Reserve', 'Labor Union', 'Affirmative Action', 'Barack Obama']
# 194
# Accuracy:0.46153846153846156
# 21/48
# Gold Standard
# ['Electoral College', 'Military Intervention', 'Internet Censorship', 'Redistribution', 'Stimulus Spending']
# 290
# Accuracy:0.4827586206896552
# 22/48
# Gun Rights
# ['Death Penalty', 'Smoking Ban', 'Homeschooling', 'Legalized Prostitution', 'Gay Marriage']
# 444
# Accuracy:0.6966292134831461
# 23/48
# Homeschooling
# ['Capitalism', 'Barack Obama', 'Legalized Prostitution', 'Globalization', 'Affirmative Action']
# 260
# Accuracy:0.5192307692307693
# 24/48
# Internet Censorship
# ['Electoral College', 'Military Intervention', 'Gold Standard', 'Torture', 'Flat Tax']
# 102
# Accuracy:0.5238095238095238
# 25/48
# Iran-Iraq War
# ['Torture', 'War on Terror', 'Internet Censorship', 'Electoral College', 'Gold Standard']
# 130
# Accuracy:0.38461538461538464
# 26/48
# Labor Union
# ['National Health Care', 'Social Security', 'Welfare', 'Term Limits', 'Progressive Tax']
# 500
# Accuracy:0.69
# 27/48
# Legalized Prostitution
# ['Globalization', 'Labor Union', 'National Health Care', 'Animal Rights', 'Barack Obama']
# 164
# Accuracy:0.45454545454545453
# 28/48
# Medicaid & Medicare
# ['Minimum Wage', 'Euthanasia', 'Social Programs', 'Civil Unions', 'United Nations']
# 386
# Accuracy:0.782051282051282
# 29/48
# Medical Marijuana
# ['Environmental Protection', 'Gay Marriage', 'Drug Legalization', 'Animal Rights', 'Abortion']
# 142
# Accuracy:0.4827586206896552
# 30/48
# Military Intervention
# ['Electoral College', 'Flat Tax', 'Internet Censorship', 'Gold Standard', 'Border Fence']
# 328
# Accuracy:0.48484848484848486
# 31/48
# Minimum Wage
# ['United Nations', 'Civil Unions', 'Welfare', 'Social Programs', 'Social Security']
# 580
# Accuracy:0.6810344827586207
# 32/48
# National Health Care
# ['Labor Union', 'Social Security', 'Welfare', 'Legalized Prostitution', 'United Nations']
# 340
# Accuracy:0.6176470588235294
# 33/48
# National Retail Sales Tax
# ['Stimulus Spending', 'Redistribution', 'Socialism', 'Occupy Movement', 'European Union']
# 272
# Accuracy:0.5454545454545454
# 34/48
# Occupy Movement
# ['Socialism', 'Stimulus Spending', 'Redistribution', 'Estate Tax', 'European Union']
# 300
# Accuracy:0.7166666666666667
# 35/48
# Progressive Tax
# ['Affirmative Action', 'Estate Tax', 'Term Limits', 'Socialism', 'Labor Union']
# 348
# Accuracy:0.5428571428571428
# 36/48
# Racial Profiling
# ['Border Fence', 'War in Afghanistan', 'Flat Tax', 'Military Intervention', 'Death Penalty']
# 216
# Accuracy:0.5
# 37/48
# Redistribution
# ['Stimulus Spending', 'Occupy Movement', 'Socialism', 'European Union', 'National Retail Sales Tax']
# 288
# Accuracy:0.6724137931034483
# 38/48
# Smoking Ban
# ['Term Limits', 'Affirmative Action', 'Progressive Tax', 'Estate Tax', 'Labor Union']
# 722
# Accuracy:0.4689655172413793
# 39/48
# Social Programs
# ['United Nations', 'Social Security', 'Welfare', 'Minimum Wage', 'Civil Unions']
# 522
# Accuracy:0.7619047619047619
# 40/48
# Social Security
# ['Welfare', 'United Nations', 'Social Programs', 'Minimum Wage', 'Civil Unions']
# 560
# Accuracy:0.6785714285714286
# 41/48
# Socialism
# ['Occupy Movement', 'Estate Tax', 'Stimulus Spending', 'European Union', 'Redistribution']
# 300
# Accuracy:0.7166666666666667
# 42/48
# Stimulus Spending
# ['Redistribution', 'Occupy Movement', 'Socialism', 'European Union', 'National Retail Sales Tax']
# 284
# Accuracy:0.42105263157894735
# 43/48
# Term Limits
# ['Smoking Ban', 'Social Security', 'Progressive Tax', 'Affirmative Action', 'Social Programs']
# 448
# Accuracy:0.35555555555555557
# 44/48
# Torture
# ['Internet Censorship', 'Iran-Iraq War', 'War on Terror', 'Electoral College', 'Military Intervention']
# 304
# Accuracy:0.5901639344262295
# 45/48
# United Nations
# ['Welfare', 'Social Security', 'Minimum Wage', 'Social Programs', 'Civil Unions']
# 570
# Accuracy:0.5877192982456141
# 46/48
# War in Afghanistan
# ['Racial Profiling', 'Death Penalty', 'Border Fence', 'Flat Tax', 'Military Intervention']
# 238
# Accuracy:0.4583333333333333
# 47/48
# War on Terror
# ['Iran-Iraq War', 'Border Fence', 'Internet Censorship', 'Torture', 'Military Intervention']
# 376
# Accuracy:0.4342105263157895
# 48/48
# Welfare
# ['Social Security', 'United Nations', 'Social Programs', 'Minimum Wage', 'Civil Unions']
# 666
# Accuracy:0.7238805970149254
# {'Abortion': 0.717948717948718, 'Affirmative Action': 0.5192307692307693, 'Animal Rights': 0.5, 'Barack Obama': 0.45098039215686275, 'Border Fence': 0.5232558139534884, 'Capitalism': 0.5526315789473685, 'Civil Unions': 0.5714285714285714, 'Death Penalty': 0.6, 'Drug Legalization': 0.5409836065573771, 'Electoral College': 0.5333333333333333, 'Environmental Protection': 0.5121951219512195, 'Estate Tax': 0.5862068965517241, 'European Union': 0.5, 'Euthanasia': 0.40384615384615385, 'Federal Reserve': 0.532258064516129, 'Flat Tax': 0.40816326530612246, 'Free Trade': 0.53125, 'Gay Marriage': 0.4166666666666667, 'Global Warming Exists': 0.6, 'Globalization': 0.46153846153846156, 'Gold Standard': 0.4827586206896552, 'Gun Rights': 0.6966292134831461, 'Homeschooling': 0.5192307692307693, 'Internet Censorship': 0.5238095238095238, 'Iran-Iraq War': 0.38461538461538464, 'Labor Union': 0.69, 'Legalized Prostitution': 0.45454545454545453, 'Medicaid & Medicare': 0.782051282051282, 'Medical Marijuana': 0.4827586206896552, 'Military Intervention': 0.48484848484848486, 'Minimum Wage': 0.6810344827586207, 'National Health Care': 0.6176470588235294, 'National Retail Sales Tax': 0.5454545454545454, 'Occupy Movement': 0.7166666666666667, 'Progressive Tax': 0.5428571428571428, 'Racial Profiling': 0.5, 'Redistribution': 0.6724137931034483, 'Smoking Ban': 0.4689655172413793, 'Social Programs': 0.7619047619047619, 'Social Security': 0.6785714285714286, 'Socialism': 0.7166666666666667, 'Stimulus Spending': 0.42105263157894735, 'Term Limits': 0.35555555555555557, 'Torture': 0.5901639344262295, 'United Nations': 0.5877192982456141, 'War in Afghanistan': 0.4583333333333333, 'War on Terror': 0.4342105263157895, 'Welfare': 0.7238805970149254}
# 1/48
# Abortion
# ['Global Warming Exists', 'Drug Legalization', 'Environmental Protection', 'Medical Marijuana', 'Euthanasia', 'Medicaid & Medicare']
# 318
# Accuracy:0.421875
# 2/48
# Affirmative Action
# ['Estate Tax', 'Progressive Tax', 'Socialism', 'Term Limits', 'Occupy Movement', 'Smoking Ban']
# 240
# Accuracy:0.5625
# 3/48
# Animal Rights
# ['Civil Unions', 'Environmental Protection', 'Medical Marijuana', 'Drug Legalization', 'Gay Marriage', 'Legalized Prostitution']
# 228
# Accuracy:0.4782608695652174
# 4/48
# Barack Obama
# ['European Union', 'Socialism', 'Occupy Movement', 'Affirmative Action', 'Estate Tax', 'Progressive Tax']
# 240
# Accuracy:0.4375
# 5/48
# Border Fence
# ['Racial Profiling', 'Flat Tax', 'Military Intervention', 'War on Terror', 'Internet Censorship', 'Electoral College']
# 364
# Accuracy:0.5205479452054794
# 6/48
# Capitalism
# ['Homeschooling', 'Free Trade', 'Electoral College', 'Gold Standard', 'European Union', 'Barack Obama']
# 162
# Accuracy:0.6363636363636364
# 7/48
# Civil Unions
# ['Minimum Wage', 'United Nations', 'Welfare', 'Social Programs', 'Social Security', 'Euthanasia']
# 336
# Accuracy:0.6323529411764706
# 8/48
# Death Penalty
# ['War in Afghanistan', 'Racial Profiling', 'Border Fence', 'Gun Rights', 'Flat Tax', 'Military Intervention']
# 438
# Accuracy:0.42045454545454547
# 9/48
# Drug Legalization
# ['Abortion', 'Environmental Protection', 'Medical Marijuana', 'Global Warming Exists', 'Civil Unions', 'Animal Rights']
# 262
# Accuracy:0.5471698113207547
# 10/48
# Electoral College
# ['Gold Standard', 'Military Intervention', 'Internet Censorship', 'Flat Tax', 'Federal Reserve', 'Capitalism']
# 206
# Accuracy:0.5476190476190477
# 11/48
# Environmental Protection
# ['Medical Marijuana', 'Global Warming Exists', 'Abortion', 'Drug Legalization', 'Animal Rights', 'Minimum Wage']
# 192
# Accuracy:0.41025641025641024
# 12/48
# Estate Tax
# ['Affirmative Action', 'Progressive Tax', 'Socialism', 'Occupy Movement', 'Stimulus Spending', 'Redistribution']
# 270
# Accuracy:0.48148148148148145
# 13/48
# European Union
# ['Socialism', 'Occupy Movement', 'Stimulus Spending', 'Barack Obama', 'Redistribution', 'Free Trade']
# 268
# Accuracy:0.5740740740740741
# 14/48
# Euthanasia
# ['Medicaid & Medicare', 'Civil Unions', 'Minimum Wage', 'Social Programs', 'Abortion', 'United Nations']
# 240
# Accuracy:0.4375
# 15/48
# Federal Reserve
# ['Flat Tax', 'Occupy Movement', 'Estate Tax', 'Affirmative Action', 'Socialism', 'Globalization']
# 276
# Accuracy:0.48214285714285715
# 16/48
# Flat Tax
# ['Military Intervention', 'Federal Reserve', 'Gold Standard', 'Electoral College', 'Border Fence', 'Racial Profiling']
# 230
# Accuracy:0.5869565217391305
# 17/48
# Free Trade
# ['European Union', 'Stimulus Spending', 'Barack Obama', 'Redistribution', 'Capitalism', 'National Retail Sales Tax']
# 140
# Accuracy:0.42857142857142855
# 18/48
# Gay Marriage
# ['Medical Marijuana', 'Animal Rights', 'Environmental Protection', 'National Health Care', 'Drug Legalization', 'Legalized Prostitution']
# 170
# Accuracy:0.5882352941176471
# 19/48
# Global Warming Exists
# ['Abortion', 'Environmental Protection', 'Drug Legalization', 'Medical Marijuana', 'Medicaid & Medicare', 'Euthanasia']
# 302
# Accuracy:0.5081967213114754
# 20/48
# Globalization
# ['Legalized Prostitution', 'Federal Reserve', 'Labor Union', 'Affirmative Action', 'Barack Obama', 'Progressive Tax']
# 178
# Accuracy:0.5
# 21/48
# Gold Standard
# ['Electoral College', 'Military Intervention', 'Internet Censorship', 'Redistribution', 'Stimulus Spending', 'Flat Tax']
# 266
# Accuracy:0.48148148148148145
# 22/48
# Gun Rights
# ['Death Penalty', 'Smoking Ban', 'Homeschooling', 'Legalized Prostitution', 'Gay Marriage', 'Drug Legalization']
# 406
# Accuracy:0.5487804878048781
# 23/48
# Homeschooling
# ['Capitalism', 'Barack Obama', 'Legalized Prostitution', 'Globalization', 'Affirmative Action', 'Federal Reserve']
# 216
# Accuracy:0.5
# 24/48
# Internet Censorship
# ['Electoral College', 'Military Intervention', 'Gold Standard', 'Torture', 'Flat Tax', 'War on Terror']
# 102
# Accuracy:0.38095238095238093
# 25/48
# Iran-Iraq War
# ['Torture', 'War on Terror', 'Internet Censorship', 'Electoral College', 'Gold Standard', 'Military Intervention']
# 124
# Accuracy:0.48
# 26/48
# Labor Union
# ['National Health Care', 'Social Security', 'Welfare', 'Term Limits', 'Progressive Tax', 'United Nations']
# 480
# Accuracy:0.59375
# 27/48
# Legalized Prostitution
# ['Globalization', 'Labor Union', 'National Health Care', 'Animal Rights', 'Barack Obama', 'Homeschooling']
# 138
# Accuracy:0.5357142857142857
# 28/48
# Medicaid & Medicare
# ['Minimum Wage', 'Euthanasia', 'Social Programs', 'Civil Unions', 'United Nations', 'Welfare']
# 360
# Accuracy:0.6805555555555556
# 29/48
# Medical Marijuana
# ['Environmental Protection', 'Gay Marriage', 'Drug Legalization', 'Animal Rights', 'Abortion', 'Global Warming Exists']
# 124
# Accuracy:0.4
# 30/48
# Military Intervention
# ['Electoral College', 'Flat Tax', 'Internet Censorship', 'Gold Standard', 'Border Fence', 'Federal Reserve']
# 282
# Accuracy:0.49122807017543857
# 31/48
# Minimum Wage
# ['United Nations', 'Civil Unions', 'Welfare', 'Social Programs', 'Social Security', 'Medicaid & Medicare']
# 554
# Accuracy:0.6216216216216216
# 32/48
# National Health Care
# ['Labor Union', 'Social Security', 'Welfare', 'Legalized Prostitution', 'United Nations', 'Term Limits']
# 300
# Accuracy:0.5
# 33/48
# National Retail Sales Tax
# ['Stimulus Spending', 'Redistribution', 'Socialism', 'Occupy Movement', 'European Union', 'Estate Tax']
# 254
# Accuracy:0.39215686274509803
# 34/48
# Occupy Movement
# ['Socialism', 'Stimulus Spending', 'Redistribution', 'Estate Tax', 'European Union', 'Affirmative Action']
# 258
# Accuracy:0.46153846153846156
# 35/48
# Progressive Tax
# ['Affirmative Action', 'Estate Tax', 'Term Limits', 'Socialism', 'Labor Union', 'Occupy Movement']
# 314
# Accuracy:0.42857142857142855
# 36/48
# Racial Profiling
# ['Border Fence', 'War in Afghanistan', 'Flat Tax', 'Military Intervention', 'Death Penalty', 'Internet Censorship']
# 210
# Accuracy:0.6190476190476191
# 37/48
# Redistribution
# ['Stimulus Spending', 'Occupy Movement', 'Socialism', 'European Union', 'National Retail Sales Tax', 'Estate Tax']
# 276
# Accuracy:0.42857142857142855
# 38/48
# Smoking Ban
# ['Term Limits', 'Affirmative Action', 'Progressive Tax', 'Estate Tax', 'Labor Union', 'Social Security']
# 686
# Accuracy:0.5144927536231884
# 39/48
# Social Programs
# ['United Nations', 'Social Security', 'Welfare', 'Minimum Wage', 'Civil Unions', 'Medicaid & Medicare']
# 496
# Accuracy:0.7
# 40/48
# Social Security
# ['Welfare', 'United Nations', 'Social Programs', 'Minimum Wage', 'Civil Unions', 'Labor Union']
# 508
# Accuracy:0.7647058823529411
# 41/48
# Socialism
# ['Occupy Movement', 'Estate Tax', 'Stimulus Spending', 'European Union', 'Redistribution', 'Affirmative Action']
# 260
# Accuracy:0.8269230769230769
# 42/48
# Stimulus Spending
# ['Redistribution', 'Occupy Movement', 'Socialism', 'European Union', 'National Retail Sales Tax', 'Estate Tax']
# 270
# Accuracy:0.5
# 43/48
# Term Limits
# ['Smoking Ban', 'Social Security', 'Progressive Tax', 'Affirmative Action', 'Social Programs', 'United Nations']
# 426
# Accuracy:0.4883720930232558
# 44/48
# Torture
# ['Internet Censorship', 'Iran-Iraq War', 'War on Terror', 'Electoral College', 'Military Intervention', 'Border Fence']
# 280
# Accuracy:0.5178571428571429
# 45/48
# United Nations
# ['Welfare', 'Social Security', 'Minimum Wage', 'Social Programs', 'Civil Unions', 'Term Limits']
# 512
# Accuracy:0.5436893203883495
# 46/48
# War in Afghanistan
# ['Racial Profiling', 'Death Penalty', 'Border Fence', 'Flat Tax', 'Military Intervention', 'Federal Reserve']
# 188
# Accuracy:0.5
# 47/48
# War on Terror
# ['Iran-Iraq War', 'Border Fence', 'Internet Censorship', 'Torture', 'Military Intervention', 'Electoral College']
# 308
# Accuracy:0.532258064516129
# 48/48
# Welfare
# ['Social Security', 'United Nations', 'Social Programs', 'Minimum Wage', 'Civil Unions', 'Labor Union']
# 602
# Accuracy:0.6942148760330579
# {'Abortion': 0.421875, 'Affirmative Action': 0.5625, 'Animal Rights': 0.4782608695652174, 'Barack Obama': 0.4375, 'Border Fence': 0.5205479452054794, 'Capitalism': 0.6363636363636364, 'Civil Unions': 0.6323529411764706, 'Death Penalty': 0.42045454545454547, 'Drug Legalization': 0.5471698113207547, 'Electoral College': 0.5476190476190477, 'Environmental Protection': 0.41025641025641024, 'Estate Tax': 0.48148148148148145, 'European Union': 0.5740740740740741, 'Euthanasia': 0.4375, 'Federal Reserve': 0.48214285714285715, 'Flat Tax': 0.5869565217391305, 'Free Trade': 0.42857142857142855, 'Gay Marriage': 0.5882352941176471, 'Global Warming Exists': 0.5081967213114754, 'Globalization': 0.5, 'Gold Standard': 0.48148148148148145, 'Gun Rights': 0.5487804878048781, 'Homeschooling': 0.5, 'Internet Censorship': 0.38095238095238093, 'Iran-Iraq War': 0.48, 'Labor Union': 0.59375, 'Legalized Prostitution': 0.5357142857142857, 'Medicaid & Medicare': 0.6805555555555556, 'Medical Marijuana': 0.4, 'Military Intervention': 0.49122807017543857, 'Minimum Wage': 0.6216216216216216, 'National Health Care': 0.5, 'National Retail Sales Tax': 0.39215686274509803, 'Occupy Movement': 0.46153846153846156, 'Progressive Tax': 0.42857142857142855, 'Racial Profiling': 0.6190476190476191, 'Redistribution': 0.42857142857142855, 'Smoking Ban': 0.5144927536231884, 'Social Programs': 0.7, 'Social Security': 0.7647058823529411, 'Socialism': 0.8269230769230769, 'Stimulus Spending': 0.5, 'Term Limits': 0.4883720930232558, 'Torture': 0.5178571428571429, 'United Nations': 0.5436893203883495, 'War in Afghanistan': 0.5, 'War on Terror': 0.532258064516129, 'Welfare': 0.6942148760330579}
# 1/48
# Abortion
# ['Global Warming Exists', 'Drug Legalization', 'Environmental Protection', 'Medical Marijuana', 'Euthanasia', 'Medicaid & Medicare', 'Minimum Wage']
# 308
# Accuracy:0.5645161290322581
# 2/48
# Affirmative Action
# ['Estate Tax', 'Progressive Tax', 'Socialism', 'Term Limits', 'Occupy Movement', 'Smoking Ban', 'Barack Obama']
# 204
# Accuracy:0.43902439024390244
# 3/48
# Animal Rights
# ['Civil Unions', 'Environmental Protection', 'Medical Marijuana', 'Drug Legalization', 'Gay Marriage', 'Legalized Prostitution', 'Minimum Wage']
# 218
# Accuracy:0.4772727272727273
# 4/48
# Barack Obama
# ['European Union', 'Socialism', 'Occupy Movement', 'Affirmative Action', 'Estate Tax', 'Progressive Tax', 'Stimulus Spending']
# 218
# Accuracy:0.6136363636363636
# 5/48
# Border Fence
# ['Racial Profiling', 'Flat Tax', 'Military Intervention', 'War on Terror', 'Internet Censorship', 'Electoral College', 'Gold Standard']
# 308
# Accuracy:0.4032258064516129
# 6/48
# Capitalism
# ['Homeschooling', 'Free Trade', 'Electoral College', 'Gold Standard', 'European Union', 'Barack Obama', 'Occupy Movement']
# 146
# Accuracy:0.4
# 7/48
# Civil Unions
# ['Minimum Wage', 'United Nations', 'Welfare', 'Social Programs', 'Social Security', 'Euthanasia', 'Medicaid & Medicare']
# 320
# Accuracy:0.484375
# 8/48
# Death Penalty
# ['War in Afghanistan', 'Racial Profiling', 'Border Fence', 'Gun Rights', 'Flat Tax', 'Military Intervention', 'Homeschooling']
# 386
# Accuracy:0.3974358974358974
# 9/48
# Drug Legalization
# ['Abortion', 'Environmental Protection', 'Medical Marijuana', 'Global Warming Exists', 'Civil Unions', 'Animal Rights', 'Minimum Wage']
# 246
# Accuracy:0.58
# 10/48
# Electoral College
# ['Gold Standard', 'Military Intervention', 'Internet Censorship', 'Flat Tax', 'Federal Reserve', 'Capitalism', 'Redistribution']
# 176
# Accuracy:0.6111111111111112
# 11/48
# Environmental Protection
# ['Medical Marijuana', 'Global Warming Exists', 'Abortion', 'Drug Legalization', 'Animal Rights', 'Minimum Wage', 'Civil Unions']
# 176
# Accuracy:0.4722222222222222
# 12/48
# Estate Tax
# ['Affirmative Action', 'Progressive Tax', 'Socialism', 'Occupy Movement', 'Stimulus Spending', 'Redistribution', 'Term Limits']
# 254
# Accuracy:0.5294117647058824
# 13/48
# European Union
# ['Socialism', 'Occupy Movement', 'Stimulus Spending', 'Barack Obama', 'Redistribution', 'Free Trade', 'National Retail Sales Tax']
# 240
# Accuracy:0.5208333333333334
# 14/48
# Euthanasia
# ['Medicaid & Medicare', 'Civil Unions', 'Minimum Wage', 'Social Programs', 'Abortion', 'United Nations', 'Drug Legalization']
# 226
# Accuracy:0.5434782608695652
# 15/48
# Federal Reserve
# ['Flat Tax', 'Occupy Movement', 'Estate Tax', 'Affirmative Action', 'Socialism', 'Globalization', 'Gold Standard']
# 246
# Accuracy:0.42
# 16/48
# Flat Tax
# ['Military Intervention', 'Federal Reserve', 'Gold Standard', 'Electoral College', 'Border Fence', 'Racial Profiling', 'Internet Censorship']
# 228
# Accuracy:0.43478260869565216
# 17/48
# Free Trade
# ['European Union', 'Stimulus Spending', 'Barack Obama', 'Redistribution', 'Capitalism', 'National Retail Sales Tax', 'Socialism']
# 132
# Accuracy:0.4074074074074074
# 18/48
# Gay Marriage
# ['Medical Marijuana', 'Animal Rights', 'Environmental Protection', 'National Health Care', 'Drug Legalization', 'Legalized Prostitution', 'Civil Unions']
# 138
# Accuracy:0.4642857142857143
# 19/48
# Global Warming Exists
# ['Abortion', 'Environmental Protection', 'Drug Legalization', 'Medical Marijuana', 'Medicaid & Medicare', 'Euthanasia', 'Minimum Wage']
# 286
# Accuracy:0.43103448275862066
# 20/48
# Globalization
# ['Legalized Prostitution', 'Federal Reserve', 'Labor Union', 'Affirmative Action', 'Barack Obama', 'Progressive Tax', 'Homeschooling']
# 160
# Accuracy:0.46875
# 21/48
# Gold Standard
# ['Electoral College', 'Military Intervention', 'Internet Censorship', 'Redistribution', 'Stimulus Spending', 'Flat Tax', 'Occupy Movement']
# 230
# Accuracy:0.5217391304347826
# 22/48
# Gun Rights
# ['Death Penalty', 'Smoking Ban', 'Homeschooling', 'Legalized Prostitution', 'Gay Marriage', 'Drug Legalization', 'National Health Care']
# 386
# Accuracy:0.5
# 23/48
# Homeschooling
# ['Capitalism', 'Barack Obama', 'Legalized Prostitution', 'Globalization', 'Affirmative Action', 'Federal Reserve', 'Socialism']
# 208
# Accuracy:0.35714285714285715
# 24/48
# Internet Censorship
# ['Electoral College', 'Military Intervention', 'Gold Standard', 'Torture', 'Flat Tax', 'War on Terror', 'Border Fence']
# 98
# Accuracy:0.6
# 25/48
# Iran-Iraq War
# ['Torture', 'War on Terror', 'Internet Censorship', 'Electoral College', 'Gold Standard', 'Military Intervention', 'Border Fence']
# 118
# Accuracy:0.5833333333333334
# 26/48
# Labor Union
# ['National Health Care', 'Social Security', 'Welfare', 'Term Limits', 'Progressive Tax', 'United Nations', 'Social Programs']
# 460
# Accuracy:0.5652173913043478
# 27/48
# Legalized Prostitution
# ['Globalization', 'Labor Union', 'National Health Care', 'Animal Rights', 'Barack Obama', 'Homeschooling', 'Civil Unions']
# 126
# Accuracy:0.5
# 28/48
# Medicaid & Medicare
# ['Minimum Wage', 'Euthanasia', 'Social Programs', 'Civil Unions', 'United Nations', 'Welfare', 'Social Security']
# 350
# Accuracy:0.6714285714285714
# 29/48
# Medical Marijuana
# ['Environmental Protection', 'Gay Marriage', 'Drug Legalization', 'Animal Rights', 'Abortion', 'Global Warming Exists', 'Minimum Wage']
# 116
# Accuracy:0.5416666666666666
# 30/48
# Military Intervention
# ['Electoral College', 'Flat Tax', 'Internet Censorship', 'Gold Standard', 'Border Fence', 'Federal Reserve', 'Racial Profiling']
# 272
# Accuracy:0.41818181818181815
# 31/48
# Minimum Wage
# ['United Nations', 'Civil Unions', 'Welfare', 'Social Programs', 'Social Security', 'Medicaid & Medicare', 'Euthanasia']
# 394
# Accuracy:0.569620253164557
# 32/48
# National Health Care
# ['Labor Union', 'Social Security', 'Welfare', 'Legalized Prostitution', 'United Nations', 'Term Limits', 'Civil Unions']
# 266
# Accuracy:0.4444444444444444
# 33/48
# National Retail Sales Tax
# ['Stimulus Spending', 'Redistribution', 'Socialism', 'Occupy Movement', 'European Union', 'Estate Tax', 'Affirmative Action']
# 228
# Accuracy:0.43478260869565216
# 34/48
# Occupy Movement
# ['Socialism', 'Stimulus Spending', 'Redistribution', 'Estate Tax', 'European Union', 'Affirmative Action', 'Barack Obama']
# 230
# Accuracy:0.391304347826087
# 35/48
# Progressive Tax
# ['Affirmative Action', 'Estate Tax', 'Term Limits', 'Socialism', 'Labor Union', 'Occupy Movement', 'Barack Obama']
# 276
# Accuracy:0.44642857142857145
# 36/48
# Racial Profiling
# ['Border Fence', 'War in Afghanistan', 'Flat Tax', 'Military Intervention', 'Death Penalty', 'Internet Censorship', 'War on Terror']
# 202
# Accuracy:0.5121951219512195
# 37/48
# Redistribution
# ['Stimulus Spending', 'Occupy Movement', 'Socialism', 'European Union', 'National Retail Sales Tax', 'Estate Tax', 'Gold Standard']
# 246
# Accuracy:0.42
# 38/48
# Smoking Ban
# ['Term Limits', 'Affirmative Action', 'Progressive Tax', 'Estate Tax', 'Labor Union', 'Social Security', 'United Nations']
# 654
# Accuracy:0.5343511450381679
# 39/48
# Social Programs
# ['United Nations', 'Social Security', 'Welfare', 'Minimum Wage', 'Civil Unions', 'Medicaid & Medicare', 'Term Limits']
# 456
# Accuracy:0.4673913043478261
# 40/48
# Social Security
# ['Welfare', 'United Nations', 'Social Programs', 'Minimum Wage', 'Civil Unions', 'Labor Union', 'Term Limits']
# 474
# Accuracy:0.7578947368421053
# 41/48
# Socialism
# ['Occupy Movement', 'Estate Tax', 'Stimulus Spending', 'European Union', 'Redistribution', 'Affirmative Action', 'Barack Obama']
# 236
# Accuracy:0.4166666666666667
# 42/48
# Stimulus Spending
# ['Redistribution', 'Occupy Movement', 'Socialism', 'European Union', 'National Retail Sales Tax', 'Estate Tax', 'Gold Standard']
# 246
# Accuracy:0.46
# 43/48
# Term Limits
# ['Smoking Ban', 'Social Security', 'Progressive Tax', 'Affirmative Action', 'Social Programs', 'United Nations', 'Labor Union']
# 394
# Accuracy:0.5063291139240507
# 44/48
# Torture
# ['Internet Censorship', 'Iran-Iraq War', 'War on Terror', 'Electoral College', 'Military Intervention', 'Border Fence', 'Gold Standard']
# 224
# Accuracy:0.4444444444444444
# 45/48
# United Nations
# ['Welfare', 'Social Security', 'Minimum Wage', 'Social Programs', 'Civil Unions', 'Term Limits', 'Medicaid & Medicare']
# 482
# Accuracy:0.6701030927835051
# 46/48
# War in Afghanistan
# ['Racial Profiling', 'Death Penalty', 'Border Fence', 'Flat Tax', 'Military Intervention', 'Federal Reserve', 'Internet Censorship']
# 184
# Accuracy:0.5405405405405406
# 47/48
# War on Terror
# ['Iran-Iraq War', 'Border Fence', 'Internet Censorship', 'Torture', 'Military Intervention', 'Electoral College', 'Racial Profiling']
# 294
# Accuracy:0.4745762711864407
# 48/48
# Welfare
# ['Social Security', 'United Nations', 'Social Programs', 'Minimum Wage', 'Civil Unions', 'Labor Union', 'Term Limits']
# 566
# Accuracy:0.6842105263157895
# {'Abortion': 0.5645161290322581, 'Affirmative Action': 0.43902439024390244, 'Animal Rights': 0.4772727272727273, 'Barack Obama': 0.6136363636363636, 'Border Fence': 0.4032258064516129, 'Capitalism': 0.4, 'Civil Unions': 0.484375, 'Death Penalty': 0.3974358974358974, 'Drug Legalization': 0.58, 'Electoral College': 0.6111111111111112, 'Environmental Protection': 0.4722222222222222, 'Estate Tax': 0.5294117647058824, 'European Union': 0.5208333333333334, 'Euthanasia': 0.5434782608695652, 'Federal Reserve': 0.42, 'Flat Tax': 0.43478260869565216, 'Free Trade': 0.4074074074074074, 'Gay Marriage': 0.4642857142857143, 'Global Warming Exists': 0.43103448275862066, 'Globalization': 0.46875, 'Gold Standard': 0.5217391304347826, 'Gun Rights': 0.5, 'Homeschooling': 0.35714285714285715, 'Internet Censorship': 0.6, 'Iran-Iraq War': 0.5833333333333334, 'Labor Union': 0.5652173913043478, 'Legalized Prostitution': 0.5, 'Medicaid & Medicare': 0.6714285714285714, 'Medical Marijuana': 0.5416666666666666, 'Military Intervention': 0.41818181818181815, 'Minimum Wage': 0.569620253164557, 'National Health Care': 0.4444444444444444, 'National Retail Sales Tax': 0.43478260869565216, 'Occupy Movement': 0.391304347826087, 'Progressive Tax': 0.44642857142857145, 'Racial Profiling': 0.5121951219512195, 'Redistribution': 0.42, 'Smoking Ban': 0.5343511450381679, 'Social Programs': 0.4673913043478261, 'Social Security': 0.7578947368421053, 'Socialism': 0.4166666666666667, 'Stimulus Spending': 0.46, 'Term Limits': 0.5063291139240507, 'Torture': 0.4444444444444444, 'United Nations': 0.6701030927835051, 'War in Afghanistan': 0.5405405405405406, 'War on Terror': 0.4745762711864407, 'Welfare': 0.6842105263157895}

# %%
np_acc = np.array(list(acc_collection[5].values()))

temp = []
for item in np_acc:
    if item > 0.5:
        temp.append(item)
        
n_acc = np.array(temp)
print(np.mean(np_acc))
# Out:
# 0.5696891162355849

# %%
import json
with open('acc_collection_continue.json', 'w') as outfile:
    json.dump(acc_collection, outfile)

# %%
with open('acc_collection_continue.json') as data_file:
    data_loaded = json.load(data_file)
    
print(data_loaded)

np_acc = np.array(list(data_loaded[8].values()))
print(np.mean(np_acc))
# Out:
# {'5': {'Abortion': 0.5916666666666667, 'Affirmative Action': 0.6333333333333333, 'Animal Rights': 0.6346153846153846, 'Barack Obama': 0.6779661016949152, 'Border Fence': 0.6022727272727273, 'Capitalism': 0.5227272727272727, 'Civil Unions': 0.48936170212765956, 'Death Penalty': 0.6652542372881356, 'Drug Legalization': 0.535483870967742, 'Electoral College': 0.48, 'Environmental Protection': 0.6341463414634146, 'Estate Tax': 0.43478260869565216, 'European Union': 0.40625, 'Euthanasia': 0.5, 'Federal Reserve': 0.5230769230769231, 'Flat Tax': 0.5384615384615384, 'Free Trade': 0.5294117647058824, 'Gay Marriage': 0.6052631578947368, 'Global Warming Exists': 0.5588235294117647, 'Globalization': 0.4782608695652174, 'Gold Standard': 0.5857142857142857, 'Gun Rights': 0.6774193548387096, 'Homeschooling': 0.5797101449275363, 'Internet Censorship': 0.5217391304347826, 'Iran-Iraq War': 0.59375, 'Labor Union': 0.6637931034482759, 'Legalized Prostitution': 0.425531914893617, 'Medicaid & Medicare': 0.7294117647058823, 'Medical Marijuana': 0.5, 'Military Intervention': 0.5211267605633803, 'Minimum Wage': 0.7295081967213115, 'National Health Care': 0.4342105263157895, 'National Retail Sales Tax': 0.5074626865671642, 'Occupy Movement': 0.5138888888888888, 'Progressive Tax': 0.7228915662650602, 'Racial Profiling': 0.4666666666666667, 'Redistribution': 0.7272727272727273, 'Smoking Ban': 0.5030674846625767, 'Social Programs': 0.7874015748031497, 'Social Security': 0.6838235294117647, 'Socialism': 0.48484848484848486, 'Stimulus Spending': 0.6515151515151515, 'Term Limits': 0.5263157894736842, 'Torture': 0.5147058823529411, 'United Nations': 0.5845070422535211, 'War in Afghanistan': 0.568, 'War on Terror': 0.4823529411764706, 'Welfare': 0.6172839506172839}, '6': {'Abortion': 0.717948717948718, 'Affirmative Action': 0.5192307692307693, 'Animal Rights': 0.5, 'Barack Obama': 0.45098039215686275, 'Border Fence': 0.5232558139534884, 'Capitalism': 0.5526315789473685, 'Civil Unions': 0.5714285714285714, 'Death Penalty': 0.6, 'Drug Legalization': 0.5409836065573771, 'Electoral College': 0.5333333333333333, 'Environmental Protection': 0.5121951219512195, 'Estate Tax': 0.5862068965517241, 'European Union': 0.5, 'Euthanasia': 0.40384615384615385, 'Federal Reserve': 0.532258064516129, 'Flat Tax': 0.40816326530612246, 'Free Trade': 0.53125, 'Gay Marriage': 0.4166666666666667, 'Global Warming Exists': 0.6, 'Globalization': 0.46153846153846156, 'Gold Standard': 0.4827586206896552, 'Gun Rights': 0.6966292134831461, 'Homeschooling': 0.5192307692307693, 'Internet Censorship': 0.5238095238095238, 'Iran-Iraq War': 0.38461538461538464, 'Labor Union': 0.69, 'Legalized Prostitution': 0.45454545454545453, 'Medicaid & Medicare': 0.782051282051282, 'Medical Marijuana': 0.4827586206896552, 'Military Intervention': 0.48484848484848486, 'Minimum Wage': 0.6810344827586207, 'National Health Care': 0.6176470588235294, 'National Retail Sales Tax': 0.5454545454545454, 'Occupy Movement': 0.7166666666666667, 'Progressive Tax': 0.5428571428571428, 'Racial Profiling': 0.5, 'Redistribution': 0.6724137931034483, 'Smoking Ban': 0.4689655172413793, 'Social Programs': 0.7619047619047619, 'Social Security': 0.6785714285714286, 'Socialism': 0.7166666666666667, 'Stimulus Spending': 0.42105263157894735, 'Term Limits': 0.35555555555555557, 'Torture': 0.5901639344262295, 'United Nations': 0.5877192982456141, 'War in Afghanistan': 0.4583333333333333, 'War on Terror': 0.4342105263157895, 'Welfare': 0.7238805970149254}, '7': {'Abortion': 0.421875, 'Affirmative Action': 0.5625, 'Animal Rights': 0.4782608695652174, 'Barack Obama': 0.4375, 'Border Fence': 0.5205479452054794, 'Capitalism': 0.6363636363636364, 'Civil Unions': 0.6323529411764706, 'Death Penalty': 0.42045454545454547, 'Drug Legalization': 0.5471698113207547, 'Electoral College': 0.5476190476190477, 'Environmental Protection': 0.41025641025641024, 'Estate Tax': 0.48148148148148145, 'European Union': 0.5740740740740741, 'Euthanasia': 0.4375, 'F ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-e80aad19c3cf> in <module>
#       4 print(data_loaded)
#       5
# ----> 6 np_acc = np.array(list(data_loaded[8].values()))
#       7 print(np.mean(np_acc))
#
# KeyError: 8

# %%
# emb_acc = acc_collection
print(acc_collection)
print(emb_acc)
print(all_emb_acc)

# %%
# coll = []
# acc_collection = dict()
# list_len = len(big_issues_list)

# target_list = ['political_ideology', 'education', 'gender', "religious_ideology"]

# # target_list = ['political_ideology','education', 'gender', "religious_ideology", "party", "ethnicity"]
# valid_users, criterion = user_filter(users, target_list, 5)

# for k in [1]:
#     for i in range(list_len):
    
# #     target = big_issues_list[i]
# #     print(str(i) + "/"+ str(list_len))
# #     print(target)
# #     target_big_issue = [target]
    
# #     # Use all together
# #     temp = big_issues_list
# #     temp[0], temp[i] = temp[i], temp[0]
# #     target_big_issue = temp
# #     print(str(i) + "/"+ str(list_len))
# #     print(temp[0])

# #     # K

    
# #         # k = 1
# #         target = big_issues_list[i]
# #         print(str(i+1) + "/"+ str(list_len))
# #         print(target)
# #         target_big_issue = [target]

# #         aux = embedding_results[target]
# #         target_big_issue.extend(aux)
# #         print(aux)   
        
#         # Rand
#         target = big_issues_list[i]
#         print(str(i+1) + "/"+ str(list_len))
#         print(target)
#         target_big_issue = [target]
    
        
#         rand_n = 1
#         temp = np.copy(big_issues_list)
#         np.random.shuffle(temp)
        
#         aux = temp[12]
        
#         while aux in embedding_results[target]:
#             temp = np.copy(big_issues_list)
#             np.random.shuffle(temp)
#             aux = temp[12]

        
#         target_big_issue.append(aux)
#         print(aux)  
        

#         # valid_users, criterion = user_filter(users, target_list, 200)
#         unbalanced_xTr, unbalanced_yTr = get_training_set(valid_users, target_big_issue, big_issues_list, criterion, language_model)

#         xTr = []
#         yTr = []

#         number_of_0 = 0
#         number_of_1 = 0

#         # Find the smaller set
#         for i in range(len(unbalanced_xTr)):
#             if unbalanced_yTr[i][0] == 0:
#                     number_of_0 += 1
#             if unbalanced_yTr[i][0] == 1:
#                     number_of_1 += 1

#         if number_of_0 > number_of_1:
#             number_each = number_of_1
#         else:
#             number_each = number_of_0

#         number_of_0 = 0
#         number_of_1 = 0

#         for i in range(len(unbalanced_xTr)):
#             if unbalanced_yTr[i][0] == 0:
#                 if number_of_0 < number_each:
#                     xTr.append(unbalanced_xTr[i])
#                     yTr.append(unbalanced_yTr[i])
#                     number_of_0 += 1
#             if unbalanced_yTr[i][0] == 1:
#                 if number_of_1 < number_each:
#                     xTr.append(unbalanced_xTr[i])
#                     yTr.append(unbalanced_yTr[i])
#                     number_of_1 += 1

#     #     print(len(xTr), len(yTr))
#     #     print(number_of_0, number_of_1)


#         mask = np.arange(2 * number_each)
#         np.random.shuffle(mask)

#         temp_xTr = []
#         temp_yTr = []

#         for pick in mask:
#             temp_xTr.append(xTr[pick])
#             temp_yTr.append(yTr[pick])

#         xTr = temp_xTr
#         yTr = temp_yTr

#     #     print(len(xTr), len(yTr))
#     #     print(len(xTr[0]), len(yTr[0]))


#         # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#         device = torch.device("cpu")

#         m = model(len(xTr[0]), 64, 2, len(target_big_issue)).to(device)
#         optimizer = optim.SGD(m.parameters(), lr=0.1)

#         training_x = xTr[0:int(0.8 * len(xTr))]
#         training_y = yTr[0:int(0.8 * len(yTr))]
#         test_x = xTr[int(0.8 * len(xTr)):]
#         test_y = yTr[int(0.8 * len(yTr)):]

#         for epoch in (range(10)):
#             m.train()
# #             print('training')
#             start_train = time.time()
#             total_loss = 0

#             total_predictions = 0
#             correct = 0

#             for i in range(int(len(training_x)/10)):
#                 # print(torch.cuda.current_device())
#                 predictions = None
#                 gold_outputs = None
#                 loss = 0
#                 optimizer.zero_grad()

#                 for j in range(10):
#                     loss = 0

# #                     if torch.cuda.is_available():
# #                         gold_output = torch.cuda.FloatTensor(training_y[i + j], device=device)
# #                         input_seq = torch.cuda.FloatTensor(training_x[i + j], device=device)
# #                     else:
#                     gold_output = torch.FloatTensor(training_y[i + j], device=device)
#                     input_seq = torch.FloatTensor(training_x[i + j], device=device)

#                     prediction_vec, prediction = m(input_seq)

#                     total_predictions += 1
#                     # gold_outputs = []
#                     if prediction[0:2] == training_y[i + j][0:2]:
#                         correct += 1
#                     if predictions is None:
#                         predictions = [prediction_vec]
#                         gold_outputs = [gold_output]
#                     else:
#                         predictions.append(prediction_vec)
#                         gold_outputs.append(gold_output)
#                     #
#                     # for lx in range(len(gold_output)):
#                     #     tmp_loss = m.compute_loss(prediction[lx], gold_output[lx])
#                     #     loss += tmp_loss

#                 # print(torch.stack(gold_outputs))
#                 # print(torch.stack(predictions))
#                 loss = m.compute_loss(torch.stack(predictions), torch.stack(gold_outputs).squeeze())
#                 # loss = loss/len(target_big_issue)
#                 loss.backward()
#                 optimizer.step()
#                 total_loss += loss.item()
#             accuracy = correct / total_predictions
# #             print("training time: {} for epoch {}".format(time.time() - start_train, epoch))
# #             print('total loss:{}'.format(total_loss))
# #             print('training accuracy:{}'.format(accuracy))

#         m.eval()
#         predictions = 0
#         correct = 0
#         baseline = 0

#         max_score = 0
#         for i in range(int(len(test_x))):
# #             if torch.cuda.is_available():
# #                 gold_output = torch.cuda.FloatTensor(test_y[i], device=device)
# #                 input_seq = torch.cuda.FloatTensor(test_x[i], device=device)
# #             else:
#             gold_output = torch.tensor(test_y[i], device=device)
#             input_seq = torch.FloatTensor(test_x[i], device=device)

#             _, prediction = m(input_seq)

#             # print("prediction", prediction)
#             # print("test_y", test_y[i])

#             if test_y[i][0:2] == prediction[0:2]:
#                 correct += 1
#             if test_y[i][0:2] == [0.0, 1.0]:
#                 baseline += 1
#             predictions += 1

#         accuracy = correct / predictions
#         acc_collection[target] = accuracy
#         # baseline = baseline / predictions
#         assert 0 <= accuracy <= 1
#         print('Accuracy:{}'.format(accuracy))
#         # print('Baseline:{}'.format(baseline))

#     print(acc_collection)
#     coll.append(acc_collection)
# Out:
# 1/49
# Abortion
# Federal Reserve
# Accuracy:0.6103286384976526
# 2/49
# Affirmative Action
# Free Trade
# Accuracy:0.7371794871794872
# 3/49
# Animal Rights
# Environmental Protection
# Accuracy:0.6390977443609023
# 4/49
# Barack Obama
# War on Terror
# Accuracy:0.7542372881355932
# 5/49
# Border Fence
# Torture
# Accuracy:0.5138461538461538
# 6/49
# Capitalism
# Capitalism
# Accuracy:0.7037037037037037
# 7/49
# Civil Unions
# Federal Reserve
# Accuracy:0.5
# 8/49
# Death Penalty
# Animal Rights
# Accuracy:0.6582278481012658
# 9/49
# Drug Legalization
# Social Security
# Accuracy:0.6396226415094339
# 10/49
# Electoral College
# War in Afghanistan
# Accuracy:0.6043956043956044
# 11/49
# Environmental Protection
# Civil Unions
# Accuracy:0.6530612244897959
# 12/49
# Estate Tax
# Military Intervention
# Accuracy:0.6449704142011834
# 13/49
# European Union
# Euthanasia
# Accuracy:0.6127450980392157
# 14/49
# Euthanasia
# Social Security
# Accuracy:0.6101083032490975
# 15/49
# Federal Reserve
# Gun Rights
# Accuracy:0.6435185185185185
# 16/49
# Flat Tax
# United Nations
# Accuracy:0.5711009174311926
# 17/49
# Free Trade
# War on Terror
# Accuracy:0.45689655172413796
# 18/49
# Gay Marriage
# Affirmative Action
# Accuracy:0.7431693989071039
# 19/49
# Global Warming Exists
# War on Terror
# Accuracy:0.6990740740740741
# 20/49
# Globalization
# Global Warming Exists
# Accuracy:0.6284153005464481
# 21/49
# Gold Standard
# Iran-Iraq War
# Accuracy:0.6402116402116402
# 22/49
# Gun Rights
# Environmental Protection
# Accuracy:0.6309523809523809
# 23/49
# Homeschooling
# Internet Censorship
# Accuracy:0.5648535564853556
# 24/49
# Internet Censorship
# National Health Care
# Accuracy:0.4742268041237113
# 25/49
# Iran-Iraq War
# Stimulus Spending
# Accuracy:0.5625
# 26/49
# Labor Union
# Term Limits
# Accuracy:0.5485714285714286
# 27/49
# Legalized Prostitution
# Gun Rights
# Accuracy:0.658753709198813
# 28/49
# Medicaid & Medicare
# Death Penalty
# Accuracy:0.712
# 29/49
# Medical Marijuana
# Animal Rights
# Accuracy:0.6370967741935484
# 30/49
# Military Intervention
# Socialism
# Accuracy:0.668
# 31/49
# Minimum Wage
# War on Terror
# Accuracy:0.6756756756756757
# 32/49
# National Health Care
# Term Limits
# Accuracy:0.7647058823529411
# 33/49
# National Retail Sales Tax
# Electoral College
# Accuracy:0.5243243243243243
# 34/49
# Occupy Movement
# Legalized Prostitution
# Accuracy:0.5853658536585366
# 35/49
# Progressive Tax
# Iran-Iraq War
# Accuracy:0.6732456140350878
# 36/49
# Racial Profiling
# National Retail Sales Tax
# Accuracy:0.5854430379746836
# 37/49
# Redistribution
# Homeschooling
# Accuracy:0.75625
# 38/49
# Smoking Ban
# Abortion
# Accuracy:0.4750378214826021
# 39/49
# Social Programs
# Medical Marijuana
# Accuracy:0.781437125748503
# 40/49
# Social Security
# Redistribution
# Accuracy:0.59375
# 41/49
# Socialism
# National Health Care
# Accuracy:0.8195488721804511
# 42/49
# Stimulus Spending
# Barack Obama
# Accuracy:0.7197452229299363
# 43/49
# Term Limits
# Torture
# Accuracy:0.5033557046979866
# 44/49
# Torture
# Minimum Wage
# Accuracy:0.6415094339622641
# 45/49
# United Nations
# Homeschooling
# Accuracy:0.6923076923076923
# 46/49
# War in Afghanistan
# Civil Unions
# Accuracy:0.5964467005076142
# 47/49
# War on Terror
# Animal Rights
# Accuracy:0.660958904109589
# 48/49
# Welfare
# Racial Profiling
# Accuracy:0.6910569105691057
# 49/49
# Iran-Iraq War
# Medicaid & Medicare
# Accuracy:0.7194570135746606
# {'Abortion': 0.6103286384976526, 'Affirmative Action': 0.7371794871794872, 'Animal Rights': 0.6390977443609023, 'Barack Obama': 0.7542372881355932, 'Border Fence': 0.5138461538461538, 'Capitalism': 0.7037037037037037, 'Civil Unions': 0.5, 'Death Penalty': 0.6582278481012658, 'Drug Legalization': 0.6396226415094339, 'Electoral College': 0.6043956043956044, 'Environmental Protection': 0.6530612244897959, 'Estate Tax': 0.6449704142011834, 'European Union': 0.6127450980392157, 'Euthanasia': 0.6101083032490975, 'Federal Reserve': 0.6435185185185185, 'Flat Tax': 0.5711009174311926, 'Free Trade': 0.45689655172413796, 'Gay Marriage': 0.7431693989071039, 'Global Warming Exists': 0.6990740740740741, 'Globalization': 0.6284153005464481, 'Gold Standard': 0.6402116402116402, 'Gun Rights': 0.6309523809523809, 'Homeschooling': 0.5648535564853556, 'Internet Censorship': 0.4742268041237113, 'Iran-Iraq War': 0.7194570135746606, 'Labor Union': 0.5485714285714286, 'Legalized Prostitution': 0.658753709198813, 'Medicaid & Medicare': 0.712, 'Medical Marijuana': 0.6370967741935484, 'Military Intervention': 0.668, 'Minimum Wage': 0.6756756756756757, 'National Health Care': 0.7647058823529411, 'National Retail Sales Tax': 0.5243243243243243, 'Occupy Movement': 0.5853658536585366, 'Progressive Tax': 0.6732456140350878, 'Racial Profiling': 0.5854430379746836, 'Redistribution': 0.75625, 'Smoking Ban': 0.4750378214826021, 'Social Programs': 0.781437125748503, 'Social Security': 0.59375, 'Socialism': 0.8195488721804511, 'Stimulus Spending': 0.7197452229299363, 'Term Limits': 0.5033557046979866, 'Torture': 0.6415094339622641, 'United Nations': 0.6923076923076923, 'War in Afghanistan': 0.5964467005076142, 'War on Terror': 0.660958904109589, 'Welfare': 0.6910569105691057}
